# %% [markdown]
# <a href="https://colab.research.google.com/github/TreeChocobo/DADS5001/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# โหลดไฟล์ข้อมูล Netflix ที่คุณอัปโหลดไว้
df = pd.read_csv('netflix_top10_Budget_Revenue.csv')
# ดูข้อมูล 5 แถวแรก
print(df.head())
# ดูข้อมูลสรุปเบื้องต้น
print(df.info())
# Out:
#                              Don't Say Good Luck  Unnamed: 1  \
# 0                                 The Last House         NaN
# 1               Freefall: A Reckoning for Boeing         NaN
# 2                                       72 HOURS         NaN
# 3  The Dating App Killer: The Monica White Story         NaN
# 4                             KPop Demon Hunters         NaN
#
#                   KPop Demon Hunters                    KPop Demon Hunters.1  \
# 0  Glass Onion: A Knives Out Mystery                                  Humint
# 1                             Humint                                 Hit Man
# 2                          The Swarm  Wake Up Dead Man: A Knives Out Mystery
# 3                            Hit Man                       Once Upon a Crime
# 4          Major Grom: Plague Doctor                            Frankenstein
#
#    Unnamed: 4  2187  136  6.218564243
# 0         NaN   NaN  NaN          NaN
# 1         NaN   NaN  NaN          NaN
# ...
